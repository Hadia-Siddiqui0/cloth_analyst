# %% [markdown]
# # Exploratory analysis scratchpad
# Use this for one-off digging into a new customer file before it's formalized into `ingestion_service.py`. Nothing here should be load-bearing for the app.
